# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px; height: 163px">
# </div>

# %% [markdown]
# # Gain Actionable Insights from Twitter Data
#
# In this capstone project, you will use Structured Streaming to gain insight from streaming Twitter data.
#
# The executive team would like to have access to some key business metrics such as
# * most tweeted hashtag in last 5 minute window
# * a map of where tweets are coming from
#
# ## Instructions
# * Insert solutions wherever it says `FILL_IN`
# * Feel free to copy/paste code from the previous notebooks, where applicable
# * Run test cells to verify that your solution is correct
#
# ## Audience
# * Primary Audience: Data Engineers
# * Additional Audiences: Data Analysts and Data Scientists
#
# ## Prerequisites
# * Web browser: current versions of Google Chrome, Firefox, Safari, Microsoft Edge and
# Internet Explorer 11 on Windows 7, 8, or 10 (see <a href="https://docs.databricks.com/user-guide/supported-browsers.html#supported-browsers#" target="_blank">Supported Web Browsers</a>)
# * Databricks Runtime 4.2 or greater
# * Completed courses Spark-SQL, DataFrames or ETL-Part 1 from <a href="https://academy.databricks.com/" target="_blank">Databricks Academy</a>, or have similar knowledge
# * Have done the rest of this course

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Getting Started</h2>
#
# Run the following cell to configure our "classroom."

# %%
# %run "./Includes/Classroom-Setup"

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Step 1</h2>
# <h3>Read Streaming Data from Input Source</h3>
#
# The input source is a a Kafka feed of Twitter data
#
# For this step you will need to:
# 0. Use the `format()` operation to specify "kafka" as the type of the stream
# 0. Specify the location of the Kafka server by setting the option "kafka.bootstrap.servers" with one of the following values (depending on where you are located):
#  * **server1.databricks.training:9092** (US-Oregon)
#  * **server2.databricks.training:9092** (Singapore)
# 0. Indicate which topics to listen to by setting the option "subscribe" to "tweets"
# 0. Throttle Kafka's processing of the streams
# 0. Rewind stream to beginning when we restart notebook
# 0. Load the input data stream in as a DataFrame
# 0. Select the column `value` - cast it to a `STRING`

# %%
from pyspark.sql.functions import col

spark.conf.set("spark.sql.shuffle.partitions", sc.defaultParallelism)

kafkaServer = "server1.databricks.training:9092"   # US (Oregon)
# kafkaServer = "server2.databricks.training:9092" # Singapore

rawDF = (spark.readStream
 .format("kafka")                     # Specify "kafka" as the type of the stream
 .option("kafka.bootstrap.servers",kafkaServer)                     # Set the location of the kafka server
 .option("subscribe","tweets")                     # Indicate which topics to listen to
 .option("maxOffsetsPerTrigger",1000)                     # Throttle Kafka's processing of the streams
 .option("startingOffsets","earliest")                     # Rewind stream to beginning when we restart notebook
 .load()                     # Load the input data stream in as a DataFrame
 .select(col("value").cast("STRING"))                     # Select the "value" column and cast to a string
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TEST - Run this cell to test your solution.
schemaStr = str(rawDF.schema)

dbTest("SS-06-schema-value",     True, "(value,StringType,true)" in schemaStr)
dbTest("SS-06-is-streaming",     True, rawDF.isStreaming)

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Step 2</h2>
# <h3>A Schema for parsing JSON</h3>
#
# Becase the schema is so complex, it is being provided for you.
#
# Simply run the following cell and proceed to the next step.

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, LongType, ArrayType

twitSchema = StructType([
  StructField("hashTags", ArrayType(StringType(), False), True),
  StructField("text", StringType(), True),   
  StructField("userScreenName", StringType(), True),
  StructField("id", LongType(), True),
  StructField("createdAt", LongType(), True),
  StructField("retweetCount", IntegerType(), True),
  StructField("lang", StringType(), True),
  StructField("favoriteCount", IntegerType(), True),
  StructField("user", StringType(), True),
  StructField("place", StructType([
    StructField("coordinates", StringType(), True), 
    StructField("name", StringType(), True),
    StructField("placeType", StringType(), True),
    StructField("fullName", StringType(), True),
    StructField("countryCode", StringType(), True)]), 
  True)
])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Step 3</h2>
# <h3>Create a JSON DataFrame</h3>
#
# From the `rawDF` parse out the json subfields using `from_json`. Create a DataFrame that has fields
# * `time`
# * `json`, a nested field that has all the rest of the data
# * promote all `json` subfields to fields.

# %%
from pyspark.sql.functions import from_json, expr

cleanDF = (rawDF
 .withColumn("json", from_json(col("value"), twitSchema))                          # Add the column "json" by parsing the column "value" with "from_json"
 .select(
   expr("cast(cast(json.createdAt as double)/1000 as timestamp) as time"),   # Cast "createdAt" column properly, call it "time"
   col("json.hashTags").alias("hashTags"),                                     # Promote subfields of "json" column e.g. "json.field" to "field"
   col("json.text").alias("text"),
   col("json.userScreenName").alias("userScreenName"),
   col("json.id").alias("id"),
   col("json.retweetCount").alias("retweetCount"),
   col("json.lang").alias("lang"),
   col("json.favoriteCount").alias("favoriteCount"),
   col("json.user").alias("user"),
   col("json.place.coordinates").alias("coordinates"), 
   col("json.place.name").alias("name"),
   col("json.place.placeType").alias("placeType"),
   col("json.place.fullName").alias("fullName"),
   col("json.place.countryCode").alias("countryCode")#Repeat for each subfields of "json"
 )
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TEST - Run this cell to test your solution.
schemaStr = str(cleanDF.schema)

dbTest("SS-06-schema-hashTag",  True, "hashTags,ArrayType(StringType,true)" in schemaStr)
dbTest("SS-06-schema-text",  True, "(text,StringType,true)" in schemaStr)
dbTest("SS-06-schema-userScreenName",  True, "(userScreenName,StringType,true)" in schemaStr)
dbTest("SS-06-schema-id",  True, "(id,LongType,true)" in schemaStr)
dbTest("SS-06-schema-time",  True, "(time,TimestampType,true)" in schemaStr)
dbTest("SS-06-schema-retweetCount",  True, "(retweetCount,IntegerType,true)" in schemaStr)
dbTest("SS-06-schema-lang",  True, "(lang,StringType,true)" in schemaStr)
dbTest("SS-06-schema-favoriteCount",  True, "(favoriteCount,IntegerType,true)" in schemaStr)
dbTest("SS-06-schema-user",  True, "(user,StringType,true)" in schemaStr)
dbTest("SS-06-schema-coordinates",  True, "(coordinates,StringType,true)" in schemaStr)
dbTest("SS-06-schema-name",  True, "(name,StringType,true)" in schemaStr)
dbTest("SS-06-schema-placeType",  True, "(placeType,StringType,true)" in schemaStr)
dbTest("SS-06-schema-fullName",  True, "(fullName,StringType,true)" in schemaStr)
dbTest("SS-06-schema-countryCode",  True, "(countryCode,StringType,true)" in schemaStr)

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Step 4</h2>
# <h3>Display Twitter Data as a Table</h3>
#
# Click the left-most button in the bottom left corner.

# %%
display(cleanDF)  # display "cleanDF"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>time</th><th>hashTags</th><th>text</th><th>userScreenName</th><th>id</th><th>retweetCount</th><th>lang</th><th>favoriteCount</th><th>user</th><th>coordinates</th><th>name</th><th>placeType</th><th>fullName</th><th>countryCode</th></tr></thead><tbody><tr><td>2020-09-13T06:47:21.000+0000</td><td>List()</td><td>I be thinking back like sheesh</td><td>BabyMilo718</td><td>1305035321390903296</td><td>0</td><td>en</td><td>0</td><td>Yonder🗽</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-09-13T06:47:21.000+0000</td><td>List()</td><td>I want to eat them and i still didn't sleep</td><td>_bunbooks_</td><td>1305035321411883009</td><td>0</td><td>en</td><td>0</td><td>BunBooks</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-09-13T06:47:21.000+0000</td><td>List()</td><td>RT @lowkeyalbert: You glow different when you pray.</td><td>wnizzahh</td><td>1305035321407545345</td><td>0</td><td>en</td><td>0</td><td>ℤ𝕒𝕙𝕙𝕙</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-09-13T06:47:21.000+0000</td><td>List()</td><td>RT @Bill_Nye_Tho: hey wear your mask correctly</td><td>Cardenassss456</td><td>1305035321386528769</td><td>0</td><td>en</td><td>0</td><td>Chris Cardenas</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-09-13T06:47:21.000+0000</td><td>List()</td><td>RT @MyHustlethread: Pink or sky blue which one you rocking,Dm if you’re looking to buy dem wristwatches and also go through my media for on…</td><td>iamorjiemmanuel</td><td>1305035321390911489</td><td>0</td><td>en</td><td>0</td><td>👑Ceo</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-09-13T06:47:21.000+0000</td><td>List(img20plus)</td><td>RT @BIGRUDEFUCK: 𝖗𝖙,𝖉𝖒 #img20plus</td><td>daboyfongfux</td><td>1305035321403346944</td><td>0</td><td>en</td><td>0</td><td>ฟองฟุ</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-09-13T06:47:21.000+0000</td><td>List()</td><td>RT @dairyfreejuuls: you know its a bad day when u wake up</td><td>Andrews25687395</td><td>1305035321403469824</td><td>0</td><td>en</td><td>0</td><td>Andrews</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-09-13T06:47:21.000+0000</td><td>List()</td><td>RT @julianne_dk: 'Thankfully we are getting closer tgt. We can talk casually as friends... right?'
# 'Aren't we friends bfr filming?'
# 'Ofc, w…</td><td>HyunJi3230</td><td>1305035321399074817</td><td>0</td><td>en</td><td>0</td><td>Seo Yea Ji stan</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-09-13T06:47:21.000+0000</td><td>List()</td><td>RT @VISUALSLEGEND: late nights. https://t.co/JFMVhsVHnj</td><td>eurphorica</td><td>1305035321415856128</td><td>0</td><td>en</td><td>0</td><td>nana.</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-09-13T06:47:21.000+0000</td><td>List()</td><td>@HeLuvsLi_ 🍯🍯🍯freaks 21+ follow me I follow back freaky tweeters only 🍯🍯🍯</td><td>DaSexperience</td><td>1305035321390829574</td><td>0</td><td>en</td><td>0</td><td>Kitty Kat</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-09-13T06:47:21.000+0000</td><td>List()</td><td>RT @miwon17_: Mingyu🌟💜
# "Something like this"(the video)
# 🐱Oh, really its been a long time since this
# 🐱ㅋㅋㅋㅋㅋㅋㅋㅋ
# 🐶the memories.. ㅠ
#
# /crying ag…</td><td>bigcatbaekho</td><td>1305035321394962433</td><td>0</td><td>en</td><td>0</td><td>레온🐱</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-09-13T06:47:21.000+0000</td><td>List(FTTB, RevengeTour2020)</td><td>This supposed to come in Monday after the 1st game.   #FTTB lets go @49ers . ..#RevengeTour2020 https://t.co/IVNqC4Qu0G</td><td>CG9er</td><td>1305035321395097600</td><td>0</td><td>en</td><td>0</td><td>Yo!Chris👍</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-09-13T06:47:22.000+0000</td><td>List()</td><td>Maybe I'm the confused one</td><td>evolving_bunny4</td><td>1305035325610299393</td><td>0</td><td>en</td><td>0</td><td>A Masterpiece</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-09-13T06:47:22.000+0000</td><td>List()</td><td>@HOLY_JV 0 skips 🙈</td><td>bjorkspears</td><td>1305035325572616193</td><td>0</td><td>en</td><td>0</td><td>Axel𓅪</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-09-13T06:47:22.000+0000</td><td>List()</td><td>@412champs Browns actually make it a close game</td><td>ImMindx</td><td>1305035325597798400</td><td>0</td><td>en</td><td>0</td><td>☘️</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-09-13T06:47:22.000+0000</td><td>List()</td><td>RT @t_d_h_nair: Karnataka BJP worker held with1200 kg ganja
# https://t.co/DS89w2uWR5</td><td>nusratfehmzad</td><td>1305035325597560832</td><td>0</td><td>en</td><td>0</td><td>nusratfehmzad</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-09-13T06:47:22.000+0000</td><td>List()</td><td>RT @Azfarheri: are you okay ? cause i miss you</td><td>akmalaslan</td><td>1305035325589188609</td><td>0</td><td>en</td><td>0</td><td>mikhail ^</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-09-13T06:47:22.000+0000</td><td>List()</td><td>RT @Alythuh: personal achievement this year was making more friends... doesn’t seem like a big deal to most but I’m used to being alone, be…</td><td>EveraBoy</td><td>1305035325572550663</td><td>0</td><td>en</td><td>0</td><td>EverBoy</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-09-13T06:47:22.000+0000</td><td>List()</td><td>RT @thissithu: Good morning 💙anybody want to follow back retweet ♥️ https://t.co/OTuJuCK6Cg</td><td>HotBoy66382635</td><td>1305035325606109184</td><td>0</td><td>en</td><td>0</td><td>Hot Boy</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-09-13T06:47:22.000+0000</td><td>List()</td><td>@red22906436 @PaulBrandITV Huge article about Sweden &amp; Covid in FT this weekend</td><td>Peterhardwick17</td><td>1305035325610364930</td><td>0</td><td>en</td><td>0</td><td>Peter hardwick</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-09-13T06:47:22.000+0000</td><td>List(MAGA)</td><td>RT @realDonaldTrump: I did more in 47 months as President than Sleepy Joe Biden did in 47 years! #MAGA https://t.co/EzcAswmrYE</td><td>mo1016</td><td>1305035325597650944</td><td>0</td><td>en</td><td>0</td><td>anticcp116tw</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-09-13T06:47:22.000+0000</td><td>List()</td><td>@Trxpical_Jay @The_youngcb @ElyjahLyons @maxyman13423 @NFL I wasn’t there in the stands “booing” im just giving my… https://t.co/YzoOSBSeeA</td><td>JayleeSmith07</td><td>1305035325576806400</td><td>0</td><td>en</td><td>0</td><td>Jayell Gallagher</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-09-13T06:47:23.000+0000</td><td>List()</td><td>RT @whiteteddybear5: Thank you twitterworld 🙏 🌍 🌏 🌎 for your Rts, follows and likes 😍 😘 💋 💙💜💙good night and sweet dreams 😴 ⭐🌝⭐💤 💤 💤
# Take ca…</td><td>Metizone</td><td>1305035329766936577</td><td>0</td><td>en</td><td>0</td><td>❀𝕸𝖊𝖙𝖎𝖟𝖔𝖓𝖊❀</td><td>[]</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2020-09-13T06:47:23.000+0000</td><td>List()</td><td>RT @mysmile0603: Give away🔖🧸🤏🏻
# @HMine13 @radi__snoopy @lilmynixc @gsrw98 @myjellyheart
# location : siam
# time : 14:00
# date : 13/09/2020
# ; re…</td><td

# %%
# TEST - Run this cell to test your solution.
dbTest("SS-06-numActiveStreams", True, len(spark.streams.active) > 0)
       
print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# When you are done, stop the stream:

# %%
for s in spark.streams.active:
  s.stop()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TEST - Run this cell to test your solution.
dbTest("SS-06-numActiveStreams1", 0, len(spark.streams.active))

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Step 5</h2>
# <h3>Hashtag Processing</h3>
#
# In this exercise, we do ETL processing on the `hashTags` column.
#
# The goal is to first convert hash tags all to lower case then group tweets and count by hash tags.
#
# You will notice that `hashTags` is an array of hash tags, which you will have to break up (use `explode` function).
#
# The `explode` method allows you to split an array column into multiple rows, copying all the other columns into each new row.

# %%
from pyspark.sql.functions import explode, lower

twitCountsDF = (cleanDF      # Start with "cleanDF"
 .select(explode(col("hashTags")).alias("hashTag"),# Explode the array "hashTags" into "hashTag"
         lower(col("hashTag")))      # Convert "hashTag" to lower case                               
 .groupBy(col("hashTag"))                    # Aggregate by "hashTag"...
 .count()                    # For the aggregate, produce a count  
 .orderBy(col("count"))                    # Sort by "count"
 .limit(25)                    # Limit the result to 25 records
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TEST - Run this cell to test your solution.
schemaStr = str(twitCountsDF.schema)

dbTest("SS-06-schema-hashTag", True, "(hashTag,StringType,true)" in schemaStr)
dbTest("SS-06-schema-count",   True, "(count,LongType,false)" in schemaStr)

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Step 6</h2>
# <h3>Plot Counts of Top 25 Most Popular Hashtags</h3>
#
# Under <b>Plot Options</b>, use the following:
# * <b>Keys:</b> `hashTag`
# * <b>Values:</b> `count`
#
# In <b>Display type</b>, use <b>Pie Chart</b> and click <b>Apply</b>.
#
# Once you apply the plot options, be prepared to increase the size of the plot graphic using the resize widget in the lower right corner of the graphic area.

# %%
display(twitCountsDF) # display twitCountsDF
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>hashTag</th><th>count</th></tr></thead><tbody><tr><td>LetsStart22ndwithSAVE</td><td>1</td></tr><tr><td>COURSES</td><td>1</td></tr><tr><td>Bellator246</td><td>1</td></tr><tr><td>sex</td><td>1</td></tr><tr><td>bungomayoi</td><td>1</td></tr><tr><td>1BillionViews</td><td>1</td></tr><tr><td>sriramya</td><td>1</td></tr><tr><td>FollowDileepAddicts</td><td>1</td></tr><tr><td>원우</td><td>1</td></tr><tr><td>IPCLive</td><td>1</td></tr><tr><td>BadshaahKeWarriors</td><td>1</td></tr><tr><td>TCAS64</td><td>1</td></tr><tr><td>taehyung</td><td>1</td></tr><tr><td>Bharathiya_Culture_Matters</td><td>1</td></tr><tr><td>WeLoveYouTaehyung</td><td>1</td></tr><tr><td>BREAKING</td><td>1</td></tr><tr><td>Bitcoin</td><td>1</td></tr><tr><td>UK</td><td>1</td></tr><tr><td>AlpNavruz</td><td>1</td></tr><tr><td>Seventeen</td><td>1</td></tr><tr><td>Iran</td><td>1</td></tr><tr><td>RiseUpATL</td><td>1</td></tr><tr><td>ZICO</td><td>1</td></tr><tr><td>Jai</td><td>1</td></tr><tr><td>Sep13</td><td>1</td></tr></tbody></table></div>

# %%
# TEST - Run this cell to test your solution.
dbTest("SS-06-numActiveStreams", True, len(spark.streams.active) > 0)
       
print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# When you are done, stop the stream:

# %%
for streamingQuery in spark.streams.active:
  streamingQuery.stop()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Step 7</h2>
# <h3>Read in File with Two Letter to Three Letter Country Codes</h3>
#
# For this next part we are going to take a look at the number of requests per country.
#
# To get started, we first need a lookup table that will give us the 3-character country code.
#
# 0. Read in the file at `/mnt/training/countries/ISOCountryCodes/ISOCountryLookup.parquet`
# 0. We will be interested in the `alpha2Code` and `alpha3Code` fields later

# %%
countryCodeDF = spark.read.parquet("/mnt/training/countries/ISOCountryCodes/ISOCountryLookup.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TEST - Run this cell to test your solution.
schemaStr = str(countryCodeDF.schema)

dbTest("SS-06-schema-1", True, "(EnglishShortName,StringType,true)" in schemaStr)
dbTest("SS-06-schema-2", True, "(alpha2Code,StringType,true)" in schemaStr)
dbTest("SS-06-schema-3", True, "(alpha3Code,StringType,true)" in schemaStr)
dbTest("SS-06-schema-4", True, "(numericCode,StringType,true)" in schemaStr)
dbTest("SS-06-schema-5", True, "(ISO31662SubdivisionCode,StringType,true)" in schemaStr)
dbTest("SS-06-schema-6", True, "(independentTerritory,StringType,true)" in schemaStr)

dbTest("SS-06-streaming-7", False, countryCodeDF.isStreaming)

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Step 8</h2>
# <h3>Join Tables &amp; Aggregate By Country</h3>
#
# In `cleanDF`, there is a `countryCode` field. However, it is in the form of a two-letter country code.
#
# The `display` map expects a three-letter country code.
#
# In order to retrieve tweets with three-letter country codes, we will have to join `cleanDF` with `countryCodesDF`.

# %%
from pyspark.sql.functions import isnull
mappedDF = (cleanDF
  .filter(~isnull(col("countryCode")))                            # Filter out any nulls for "countryCode"
  .join(countryCodeDF, col("countryCode") == col("alpha2Code"))  # Join the two tables on "countryCode" and "alpha2Code"
  .groupBy("alpha3Code")                            # Aggregate by country, "alpha3Code"
  .count()                            # Produce a count of each aggregate
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TEST - Run this cell to test your solution.
schemaStr = str(mappedDF.schema)
print(schemaStr)

dbTest("SS-06-schema-1",  True, "alpha3Code,StringType,true" in schemaStr)
dbTest("SS-06-schema-2",  True, "count,LongType,false" in schemaStr)

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">StructType(List(StructField(alpha3Code,StringType,true),StructField(count,LongType,false)))
# Tests passed!
# </div>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Step 9</h2>
# <h3>Plot Tweet Counts on a World Map</h3>
#
# Under <b>Plot Options</b>, use the following:
# * <b>Keys:</b> `alpha3Code`
# * <b>Values:</b> `count`
#
# In <b>Display type</b>, use <b>World map</b> and click <b>Apply</b>.
#
# <img src="https://files.training.databricks.com/images/eLearning/Structured-Streaming/plot-options-map-06.png"/>

# %%
display(mappedDF)  # display mappedDF
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>alpha3Code</th><th>count</th></tr></thead><tbody><tr><td>IND</td><td>20</td></tr><tr><td>MWI</td><td>1</td></tr><tr><td>NZL</td><td>2</td></tr><tr><td>TUR</td><td>1</td></tr><tr><td>LKA</td><td>2</td></tr><tr><td>OMN</td><td>1</td></tr><tr><td>DEU</td><td>1</td></tr><tr><td>AUS</td><td>6</td></tr><tr><td>NGA</td><td>9</td></tr><tr><td>PHL</td><td>7</td></tr><tr><td>POL</td><td>1</td></tr><tr><td>BWA</td><td>1</td></tr><tr><td>THA</td><td>1</td></tr><tr><td>CZE</td><td>1</td></tr><tr><td>DNK</td><td>1</td></tr><tr><td>LBN</td><td>1</td></tr><tr><td>CAN</td><td>2</td></tr><tr><td>IRQ</td><td>1</td></tr><tr><td>UKR</td><td>1</td></tr><tr><td>JAM</td><td>1</td></tr><tr><td>FRA</td><td>1</td></tr><tr><td>NLD</td><td>1</td></tr><tr><td>ITA</td><td>1</td></tr><tr><td>GHA</td><td>2</td></tr><tr><td>PAK</td><td>2</td></tr><tr><td>BRA</td><td>1</td></tr><tr><td>ZAF</td><td>10</td></tr><tr><td>USA</td><td>88</td></tr><tr><td>IRL</td><td>2</td></tr><tr><td>MYS</td><td>5</td></tr><tr><td>ROU</td><td>1</td></tr><tr><td>CHN</td><td>2</td></tr><tr><td>IDN</td><td>1</td></tr><tr><td>GBR</td><td>36</td></tr><tr><td>SGP</td><td>1</td></tr><tr><td>UGA</td><td>1</td></tr></tbody></table></div>

# %%
# TEST - Run this cell to test your solution.
dbTest("SS-06-numActiveStreams", True, len(spark.streams.active) > 0)
       
print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Step 10: Write Stream</h2>
#
# Write the stream to an in-memory table
# 0. Use appropriate `format`
# 0. For this exercise, we want to append new records to the results table
# 0. Gives the query a name
# 0. Start the query
# 0. Assign the query to `mappedTable`

# %%
mappedQuery = (mappedDF 
.writeStream                               # From the DataFrame get the DataStreamWriter
.format("memory")                               # Specify the sink format as "memory"
.outputMode("complete")                               # Configure the output mode as "complete"
.queryName("mappedTablePython")                               # Name the query "mappedTablePython"
.start()                               # Start the query
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TEST  - Run this cell to test your solution.
dbTest("SS-06-isActive", True, mappedQuery.isActive)
dbTest("SS-06-name", "mappedTablePython", mappedQuery.name)

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# Wait until stream is done initializing...

# %%
untilStreamIsReady("mappedTablePython")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The stream is active and ready.
# </div>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Step 11: Use SQL Syntax to Display a Few Rows</h2>
#
# Do a basic SQL query to display all columns and, say, 10 rows.
#
# ### Why are we doing this?

# %%
# %sql
SELECT *
FROM mappedTablePython
LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>alpha3Code</th><th>count</th></tr></thead><tbody><tr><td>IND</td><td>26</td></tr><tr><td>MWI</td><td>1</td></tr><tr><td>NZL</td><td>2</td></tr><tr><td>TUR</td><td>2</td></tr><tr><td>LKA</td><td>2</td></tr><tr><td>OMN</td><td>1</td></tr><tr><td>DEU</td><td>2</td></tr><tr><td>AUS</td><td>10</td></tr><tr><td>NGA</td><td>10</td></tr><tr><td>PHL</td><td>8</td></tr></tbody></table></div>

# %%
# TEST - Run this cell to test your solution.
try: tableExists = (spark.table("mappedTablePython") is not None)
except: tableExists = False
dbTest("SS-06-1", True, tableExists)  

firstRowCol = spark.sql("SELECT * FROM mappedTablePython limit 1").first()[0]
dbTest("SS-06-rowsExist", True, len(firstRowCol) > 0) 

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Step 12: Stop Streaming Jobs</h2>
#
# Before we can conclude, we need to shut down all active streams.

# %%
for s in spark.streams.active:  # Iterate over all the active streams
  s.stop()  # Stop the stream
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TEST - Run this cell to test your solution.
dbTest("SS-06-numActiveStreams", 0, len(spark.streams.active))

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# -sandbox
# &copy; 2019 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
